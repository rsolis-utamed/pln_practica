# %% [markdown]
# #**1. Importación de librerías**

# %%
import requests # Librería para realizar llamadas http
from bs4 import BeautifulSoup # Librería para manipular documentos en formato html
import pandas as pd # Librería que permite manipular datos en dataframes

# %% [markdown]
# #**2. Definición de funciones**

# %%
# Función que permite recuperar el contenido de una página html
def fetch_html(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        print(" Contenido de la página descargado exitosamente.")
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Asegura que la solicitud fue exitosa
        soup = BeautifulSoup(response.text, 'html.parser')
        print(response.status_code)
        return soup
    else:
        print(f" Error al acceder a la página. Código de estado: {response.status_code}")

# %%
# Función que permite generar un documento csv con la información html recuperada
def generate_csv(html_content,file_name):
  lista_mensajes = []
  for post in content:
      # Eliminar las citas (quotes) de otros usuarios para limpiar el texto
      for blockquote in post.find_all('blockquote'):
          blockquote.decompose()
      # Extraer el texto limpio
      texto_mensaje = post.get_text(strip=True)

      # Guardamos en un diccionario
      lista_mensajes.append({
          "Mensaje": texto_mensaje
      })

  # 5. Crear DataFrame y guardar a CSV
  df = pd.DataFrame(lista_mensajes)

  # 'utf-8-sig' es vital para que Excel abra bien las tildes en Windows
  df.to_csv(f"{file_name}.csv", index=False, encoding='utf-8-sig')
  print(f"{file_name}.csv generated")

# %% [markdown]
# #3. Extracción de la información de los diferentes recursos web

# %%
# Dkiccionario con los recursos - urls empleados para generar el corpus
urls={
    "cotilleando":"https://www.cotilleando.com/threads/malaga-da-asco.139225/",
    "minube":"https://www.minube.com/rincon/malaga-a13124",
    "forocoches":"https://forocoches.com/foro/showthread.php?t=9441037"
   }

# %% [markdown]
# ##3.1. Recuperación y generación de datos correspondientes al origen 1

# %%
# 1. Definir la URL
source_1="cotilleando"
url_source_1 = urls[source_1]
source_name_1=f"data_{source_1}"
soup = fetch_html(url_source_1)
if soup:
    # 2. Extraer y mostrar el título de la página
    title = soup.title.string
    print(f"Título de la página: {title}")

    # 3. Extraer y mostrar todos los enlaces en la página
    content = soup.find_all('div', class_='bbWrapper')
    print(content[:20])
    generate_csv(url_source_1,source_name_1)
# Out:
#  Contenido de la página descargado exitosamente.
# 200
# Título de la página: Málaga da asco | Cotilleando - El mejor foro de cotilleos |  Desde 2004
# [<div class="bbWrapper">Pues eso... Así literal, para mi gusto Málaga da asco.<br/>
# Llevo viviendo en esta ciudad 5 años y cada vez estoy más cansada de ella.<br/>
# Está muyyy sucia y descuidada.<br/>
# La gente en general es acogedora y estupenda, pero hay cada personaje...<br/>
# Es raro el día que sales y no te piden dinero cuando vas paseando tranquilamente por la calle. <br/>
# Esto me ha pasado hasta ahora en periodo de cuarentena.<br/>
# Gente rebuscando en contenedores a plena luz del día...<br/>
# Un desastre todo! <br/>
# <br/>
# Alguien más que opine como yo???</div>, <div class="bbWrapper">Qué pena, de verdad, hace que no voy unos seis años, pero la recuerdo muy hermosa. Y todos los malagueños que conozco son gente de diez. Perita.</div>, <div class="bbWrapper">me da pena lo que dices, pase un par de temmporadas ahi y me gustaba mucho sobretodo la gente de los locales muy acogedora, caminar por las calles en las tardes era muy agradable</div>, <div class="bbWrapper">No puedo evitar tomármelo a lo personal (hasta que me mudé a Madrid para hacer la carrera Málaga había sido mi hogar), aunque sé que no tiene nada que ver conmigo. Me da pena lo que dices.<br/>
# <br/>
# Hace ya meses que no bajo hasta allí, pero para mí Málaga tiene un encanto especial y siempre la he disfrutado muchísimo. ¿Estará más sucia y con gente rebuscando en los contenedores? Pues sí, posiblemente, pero yo vivo en el centro de Madrid y te puedo decir que últimamente lo de pedir en la calle me ha pasado todas las tardes que he ido a pasear o de madrugada cuando he bajado a tirar la basura. <br/>
# <br/>
# Será que lo que comentas es más reciente de lo que yo he visto, por eso no te puedo decir mi opinión objetiva a día de hoy. Pero creo que la ciudad tiene mucho potencial y yo siempre voy a querer volver. ?</div>, <div class="bbWrapper">¿Qué dices? De lo mejor de Andalucía, pienso trasladarme allí.<br/>
# Para desastre Huelva capital y sus habitantes los más impresentables de Andalucía y diría que de toda España.</div>, <div class="bbWrapper">Málaga tendrá de todo, pero últimamente esta entre las ciudades con potencial de España.<br/>
# Ha dado un cambio a mejor impresionante, la zona del puerto, alameda.. Los barrios están mejorando y cada vez más limpios y con muy buena conexión al centro.<br/>
# <br/>
# A mi lo de pedir dinero veces puntuales, no es algo que me ocurra a diario.</div>, <div class="bbWrapper"><blockquote class="bbCodeBlock bbCodeBlock--expandable bbCodeBlock--quote js-expandWatch" data-attributes="member: 112934" data-quote="Mamuchic" data-source="post: 9953926"><div class="bbCodeBlock-title">
# <a class="bbCodeBlock-sourceJump" data-content-selector="#post-9953926" data-xf-click="attribution" href="/goto/post?id=9953926" rel="nofollow">Mamuchic dijo:</a></div><div class="bbCodeBlock-content"><div class="bbCodeBlock-expandContent js-expandContent">
# Pues eso... Así literal, para mi gusto Málaga da asco.<br/>
# Llevo viviendo en esta ciudad 5 años y cada vez estoy más cansada de ella.<br/>
# Está muyyy sucia y descuidada.<br/>
# La gente en general es acogedora y estupenda, pero hay cada personaje...<br/>
# Es raro el día que sales y no te piden dinero cuando vas paseando tranquilamente por la calle.<br/>
# Esto me ha pasado hasta ahora en periodo de cuarentena.<br/>
# Gente rebuscando en contenedores a plena luz del día...<br/>
# Un desastre todo!<br/>
# <br/>
# Alguien más que opine como yo???</div><div class="bbCodeBlock-expandLink js-expandLink"><a role="button" tabindex="0">Hacer clic para expandir...</a></div></div></blockquote><br/>
# Y a mi me ha dado asco tu comentario, así literal, porque están focalizando en una ciudad lo que es simple asco por la gente necesitada, que te pidan dinero, que te molesten, que rebusquen en las basuras ... eso es lo que te da asco, que no encierren a esa gente que hiere tu sensibilidad.<br/>
# <br/>
# Estoy de acuerdo contigo en que el Estado de Alarma está poniendo ante nuestro ojos una realidad que en la normalidad de diluye en la masa que es que en nuestras ciudades hay una serie de "personajes" como tu los llamas que son dementes, que están alcoholizados, que todo esto les importa nada, viven al margen de la ley y no acatan las normas del confinamiento porque no tienen nada más que perder y ese el problema, que el Estado no tenga armas eficaces para ayudar a estas personas aunque sea contra su voluntad. Yo vivo en la zona centro y también estoy observando lo que dices, a veces siento miedo porque este tipo de personas no están en su juicio, pero sobre todo siento pena y no que sea algo exclusivo o particular de Málaga.<br/>
# <br/>
# En Málaga, como en cualquier otra ciudad, existen albergues municipales en los que las personas sin techo pueden ir a cubrir sus necesidades básicas, pero cuando una persona tiene sus capacidades mentales alteradas, tiene una adicción o una enfermedad peor que el coronavirus esa no es su prioridad, pueden ser multados por no cumplir las normas, pero en igual medida que cualquier otro ciudadado, lo que no pueden es ser encerrados en un calabozo y tirar la llave para que no hieran tu sensibilidad.<br/>
# <br/>
# Lo que nos gusta de Málaga por un lado, el clima, el buen tiempo ... es un arma de doble filo para estas cuestiones porque permite a la gente con esta problemática deambular sin morir de hipotermia, pero esto es un problema que se da en casi todas las ciudades grandes/medianas, lo que pasa es que en las más grandes suelen dormir en las bocas de metro y tu no los ves. Tienes armas en tu poder, cuando veas a alguien que no cumple llama a la policía o llama a los servicios sociales, haz algo bueno por ellos y por la sociedad más allá de quejarte con asco.<br/>
# <br/>
# Y respecto a Málaga en si, por supuesto que hay muchas cosas mejorables, sobre todo la limpieza en los barrios, pero es una ciudad que ha tenido una evolución positiva en los últimos años que es incuestionable, sin duda la ciudad española que más se ha transformado a muchos niveles.</div>, <div class="bbWrapper"><blockquote class="bbCodeBlock bbCodeBlock--expandable bbCodeBlock--quote js-expandWatch" data-attributes="member: 112934" data-quote="Mamuchic" data-source="post: 9953926"><div class="bbCodeBlock-title">
# <a class="bbCodeBlock-sourceJump" data-content-selector="#post-9953926" data-xf-click="attribution" href="/goto/post?id=9953926" rel="nofollow">Mamuchic dijo:</a></div><div class="bbCodeBlock-content"><div class="bbCodeBlock-expandContent js-expandContent">
# Pues eso... Así literal, para mi gusto Málaga da asco.<br/>
# Llevo viviendo en esta ciudad 5 años y cada vez estoy más cansada de ella.<br/>
# Está muyyy sucia y descuidada.<br/>
# La gente en general es acogedora y estupenda, pero hay cada personaje...<br/>
# Es raro el día que sales y no te piden dinero cuando vas paseando tranquilamente por la calle.<br/>
# Esto me ha pasado hasta ahora en periodo de cuarentena.<br/>
# Gente rebuscando en contenedores a plena luz del día...<br/>
# Un desastre todo!<br/>
# <br/>
# Alguien más que opine como yo???</div><div class="bbCodeBlock-expandLink js-expandLink"><a role="button" tabindex="0">Hacer clic para expandir...</a></div></div></blockquote>Dicho sea primero que no he pisado Málaga en mi vida. Me encantaría ir, por supuesto, y espero hacerlo algún día. Lo que me ha impactado mucho es tu comentario. Que Málaga te da asco porque hay gente pidiendo y la gente rebusca en las basuras? Pero esto es en serio? Lo único salvable que leo en tu comentario es lo de la suciedad, que eso sí entiendo que al ser responsabilidad del ayuntamiento, se haga queja. Pero de lo otro? Y qué hacemos? Los encerramos donde no molesten tu paseito? Los exterminamos porque nos incomoda mirarlos? No sé si eres consciente que toda esa gente que te causa asco son PERSONAS como tú.  Que tienen la desgracia de no tener nada que llevarse a la boca ni mucho menos un techo en el que dormir. Pero nada, que a los que tienen la tripa llena y el cuerpo descansado, les da asco verlos, oye. De verdad, a veces la falta de empatía humana llega a unos extremos...</div>, <div class="bbWrapper">Yo soy un enamorado de Málaga, para mi una de las ciudades mas interesantes de todo lo que he visto. Nací en Barcelona y cuando no era un atraco era una manifestación, turistas borrachos, etc..y al final me fui, no aguantaba mas, un día vi una pelea en un atasco de dos mujeres con niños y un abuelo a hostia limpia que me quitó las ganas de seguir ahí<br/>
# <br/>
# Llevo 15 años visitando Málaga por familia política y cada día me entra mas fuerte la idea de irme a vivir allí. Guarros y incívicos hay en todas partes, incluso en pueblecitos idílicos del norte donde se supone que la gente es mas educada. <br/>
# Málaga tiene ese punto medio entra ciudad cultural y de actividad económica, historia y clima que me encanta. Lo que da asco no es Málaga sino algunos cerdos que viven ahí.</div>, <div class="bbWrapper">Otro malagueño por aquí y coincido con algunos comentarios, lo que da ASCO es la personalidad de mucha gente... pero no la ciudad... y por supuesto, no toda Málaga es tal y como hablas... es como todo, en todas las ciudades hay de todo un poco y lo que pasa es que en algunos puntos se nota más que en otros. pero oye! hay sitios peores dale otra oportunidad a Málaga, cambia de zona.</div>, <div class="bbWrapper"><blockquote class="bbCodeBlock bbCodeBlock--expandable bbCodeBlock--quote js-expandWatch" data-attributes="member: 112934" data-quote="Mamuchic" data-source="post: 9953926"><div class="bbCodeBlock-title">
# <a class="bbCodeBlock-sourceJump" data-content-selector="#post-9953926" data-xf-click="attribution" href="/goto/post?id=9953926" rel="nofollow">Mamuchic dijo:</a></div><div class="bbCodeBlock-content"><div class="bbCodeBlock-expandContent js-expandContent">
# Pues eso... Así literal, para mi gusto Málaga da asco.<br/>
# Llevo viviendo en esta ciudad 5 años y cada vez estoy más cansada de ella.<br/>
# Está muyyy sucia y descuidada.<br/>
# La gente en general es acogedora y estupenda, pero hay cada personaje...<br/>
# Es raro el día que sales y no te piden dinero cuando vas paseando tranquilamente por la calle.<br/>
# Esto me ha pasado hasta ahora en periodo de cuarentena.<br/>
# Gente rebuscando en contenedores a plena luz del día...<br/>
# Un desastre todo!<br/>
# <br/>
# Alguien más que opine como yo???</div><div class="bbCodeBlock-expandLink js-expandLink"><a role="button" tabindex="0">Hacer clic para expandir...</a></div></div></blockquote>Igual tienes que viajar un poco dentro y fuera de España para darte cuenta de la suerte que tienes y abrir un poquito los ojos.</div>, <div class="bbWrapper"><blockquote class="bbCodeBlock bbCodeBlock--expandable bbCodeBlock--quote js-expandWatch" data-attributes="member: 35154" data-quote="Sounds_Of_Summer" data-source="post: 10060881"><div class="bbCodeBlock-title">
# <a class="bbCodeBlock-sourceJump" data-content-selector="#post-10060881" data-xf-click="attribution" href="/goto/post?id=10060881" rel="nofollow">Sounds_Of_Summer dijo:</a></div><div class="bbCodeBlock-content"><div class="bbCodeBlock-expandContent js-expandContent">
# Igual tienes que viajar un poco dentro y fuera de España para darte cuenta de la suerte que tienes y abrir un poquito los ojos.</div><div class="bbCodeBlock-expandLink js-expandLink"><a role="button" tabindex="0">Hacer clic para expandir...</a></div></div></blockquote>Que esté la ciudad muy sucia es para quejarse, a la suciedad van  las ratas y con ratas te puede venir hasta la peste.<br/>
# Vale, que parece exagerado, pero el Ayuntamiento  está entre otras cosas para mantener limpia su ciudad, entiendo también que si rebuscan en los contenedores  tiraran basura fuera del mismo  y la policía está para impedirlo.</div>]
# data_cotilleando.csv generated

# %% [markdown]
# ##3.2. Recuperación y generación de datos correspondientes al origen 2

# %%
# 1. Definir la URL
source_2="minube"
url_source_2 = urls[source_2]
source_name_2=f"data_{source_2}"
soup = fetch_html(url_source_2)
if soup:
    # 2. Extraer y mostrar el título de la página
    title = soup.title.string
    print(f"Título de la página: {title}")

    # 3. Extraer y mostrar todos los enlaces en la página
    content = soup.find_all('article', class_='poiExperience')
    print(content[:20])
    generate_csv(url_source_2,source_name_2)
# Out:
#  Contenido de la página descargado exitosamente.
# 200
# Título de la página: Málaga en Málaga: 40 opiniones y 604 fotos
# [<article class="poiExperience" data-comment-id="1902925" data-user-id="5037652" id="experience5037652" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="dc1037bff9bba1fa1d1d7dd497b1314f" data-user-id="5037652" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/5037652_80x80.jpg" title="josemanuelbernalguillen"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  José Manuel Bernal Guillén
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Málaga, mucho más que la capital de la Costa del Sol</h3>
# <div class="content" data-translate-content-text="off"><p>Málaga es mucho más para mi que la capital de la Costa del Sol, la segunda ciudad de Andalucía o un importante puerto del Mediterráneo. Por cierto: ¿la capital de la Costa del Sol no es Marbella?<br/><br/>Resdí y trabajé allí durante 9 meses y la experiencia no pudo ser más gratificante:<br/><br/>-Málaga es una ciudad muy cosmopolita, una auténtica babel de lenguas, culturas,razas...lo que bajo mi punto de vista es siempre enriquecedor. La mayoría de sus gentes son hospitalarias y acogedoras y están acostumbradas a tratar bien al viajero que llega por primera vez a la ciudad.<br/><br/>-Urbanísticamente, es una ciudad funcional y moderna. Recuerdo con especial cariño las siguientes partes de la ciudad: Ciudad Jardín, barrio peculiar donde los haya; la catedral y alrededores; el puerto y alrededores; la playa de El Palo; la alcazaba y el teatro romano; la calle Larios con sus innumerables bares, cafés y tiendas, para quien guste de estas aficiones o el mercadillo de la Rosaleda, que creo recordar se celebraba o celebra en domingo.</p><div class="whiteOverlay"></div><div class="remainingText"></div></div>
# <div class="linkAction" data-translate-content-text="off" onclick="">
#  Leer más
# </div></div>
# <div class="picturesContainer"><img class="picture" data-dynamic-source="1" data-pictureid="7526188" data-src="https://images.mnstatic.com/87/8e/878e3ffb3268ba018090dbab10ee0d07.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 5037652)" src="..."/><img class="picture" data-dynamic-source="1" data-pictureid="7526163" data-src="https://images.mnstatic.com/c7/1d/c71de3b08301e95f104612ebc49e5eca.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 5037652)" src="..."/><div class="pictureBackground" onclick="Minube.services.Experiences.openUserGallery(this, 5037652)"><img class="backgroundFill" data-dynamic-source="1" data-src="https://images.mnstatic.com/e4/37/e437ecc82f45f925b12c7b1ec998f2a1.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" src="..."/><div class="totalUserPics">+12</div></div></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="5037652"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="2358693" data-user-id="4429981" id="experience4429981" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="c7dd05a9c6a48e5c39b0e6ded143c647" data-user-id="4429981" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/4429981_80x80_2.jpg" title="rafaelvilches"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  Rafael Vilches
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Mucho que ver</h3> <div class="rating">
# <div class="staticRating">
# <div class="starsRating"><div class="rating-experience active-star icon_base full-star" data-rating="1"></div><div class="rating-experience active-star icon_base full-star" data-rating="2"></div><div class="rating-experience active-star icon_base full-star" data-rating="3"></div><div class="rating-experience active-star icon_base full-star" data-rating="4"></div><div class="rating-experience active-star icon_base full-star" data-rating="5"></div></div>
# <div class="ratingSideText"><div class="ratingTextShown">Excelente</div></div></div></div>
# <div class="content" data-translate-content-text="off"><p>Capital y ciudad de referencia de la Costa del Sol, ofrece gran cantidad de actividades entre culturales y lúdicas.<br/><br/>La calle Larios, referente comercial y de ocio en la ciudad, es la principal artería que conecta la cultura con el ocio. Los museos y monumentos se entre mezclan con muchos restaurantes y locales de copas.<br/><br/>La zona de la Catedral y el Palacio Episcopal es el inicio de la ruta histórica y monumental de Málaga, para llegar hasta la Alcazaba y el teatro romano anexo a la misma. Merece la pena subir para tener la panorámica típica de la ciudad.<br/><br/>Varios importantes museos se han establecido en la ciudad, desde la fundación y museo de Pablo Picasso, hasta el Pompidou, entre otras interesantes alternativas para visitar.</p><div class="whiteOverlay"></div><div class="remainingText"></div></div>
# <div class="linkAction" data-translate-content-text="off" onclick="">
#  Leer más
# </div></div>
# <div class="picturesContainer"><img class="picture" data-dynamic-source="1" data-pictureid="9587431" data-src="https://images.mnstatic.com/c4/a3/c4a3d5ecd88a47b148b1c3bd498d8665.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 4429981)" src="..."/><img class="picture" data-dynamic-source="1" data-pictureid="9587438" data-src="https://images.mnstatic.com/64/18/641893dbd9debe706cf45cfff76a812e.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 4429981)" src="..."/><div class="pictureBackground" onclick="Minube.services.Experiences.openUserGallery(this, 4429981)"><img class="backgroundFill" data-dynamic-source="1" data-src="https://images.mnstatic.com/2a/14/2a140bdd94e67f1c327a8aee668b76aa.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" src="..."/><div class="totalUserPics">+6</div></div></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="4429981"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="1745044" data-user-id="3940681" id="experience3940681" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="d4d9b7c5cf400f24f4bc7f7c57a8bfdb" data-user-id="3940681" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/3940681_80x80.jpg" title="jaypenser"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  Elisa I. Pérez
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Sabinillas, Málaga</h3>
# <div class="content" data-translate-content-text="off"><p>Esa costa que está más allá de Marbella, dónde ya no se mueven los ricos, sino la gente sencilla, la gente que siempre ha vivido en este pueblito y que lo ha convertido en un lugar tranquilo, familiar y seguro. Sus playas son preciosas y en los días claros se suele ver el Peñón de Gibraltar. Su paseo marítimo tiene su centro en esta estatua.</p></div></div>
# <div class="picturesContainer"><img class="picture" data-dynamic-source="1" data-pictureid="7239578" data-src="https://images.mnstatic.com/f4/8d/f48d628253d69b612035596066a88967.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 3940681)" src="..."/></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="3940681"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="85737" data-user-id="71534" id="experience71534" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="b0ca22d1dfda1befc097d97fee959cfd" data-user-id="71534" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/71534_80x80_2.jpg" title="marinamarco"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  Marina&amp;Marco
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Málaga</h3>
# <div class="content" data-translate-content-text="off"><p>Ciudad Puerta entre culturas, vieja casi como los inicios del hombre, visitada desde siempre y disfrutada por todos los que se acercan a sus orillas, sus montañas y sus pueblos. Hospitalaria, cálida y luminosa, es un soplo de alegría para el corazón viajero.</p></div></div>
# <div class="picturesContainer"></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="71534"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="2297522" data-user-id="6281197" id="experience6281197" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="68e97ba8244b6f5242c0620c43863fa9" data-user-id="6281197" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/6281197_80x80_2.jpg" title="paulalizano"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  Paula Lizano
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">El frio nos dió una tregua durante 4 dias</h3>
# <div class="content" data-translate-content-text="off"><p>Enero. Saliendo de un paraje totalmente nevado, desde los pirineos catalanes, rumbo al sur de España. El frio nos dió una tregua durante 4 días. Vistas del Alcazaba de Málaga y algún rincón que otro.</p></div></div>
# <div class="picturesContainer"><img class="picture" data-dynamic-source="1" data-pictureid="8988915" data-src="https://images.mnstatic.com/0f/54/0f54e2f3433e026214ab33afa207e5b6.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 6281197)" src="..."/><img class="picture" data-dynamic-source="1" data-pictureid="8988905" data-src="https://images.mnstatic.com/ab/a4/aba4707230d51ab237a10a6797b7c87a.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" onclick="Minube.services.Experiences.openUserGallery(this, 6281197)" src="..."/><div class="pictureBackground" onclick="Minube.services.Experiences.openUserGallery(this, 6281197)"><img class="backgroundFill" data-dynamic-source="1" data-src="https://images.mnstatic.com/06/65/0665eebe711ac23bcb4dd494d233b0a0.jpg?quality=75&amp;format=png&amp;fit=crop&amp;width=65&amp;height=65&amp;aspect_ratio=65%3A65" src="..."/><div class="totalUserPics">+3</div></div></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="6281197"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="368861" data-user-id="54173" id="experience54173" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="3d5946d01ea07db9fd4e4b1729ce8b63" data-user-id="54173" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/54173_80x80_22.jpg" title="miguelangelcartagena"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  miguel a. cartagena
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Descubre Málaga en tan solo 4 minutos. ...</h3>
# <div class="content" data-translate-content-text="off"><p>Descubre Málaga en tan solo 4 minutos. Disfruta de esta fantástica provincia en la que encontrarás paisajes espectaculares. Una provincia con un gran patrimonio histórico en cada localidad que visites. Os dejo este fotomontaje donde descubriréis parte de lo que os ofrece esta bella tierra.<br/><br/>Un saludo viajeros</p></div></div>
# <div class="picturesContainer"></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="54173"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>, <article class="poiExperience" data-comment-id="2304264" data-user-id="6312684" id="experience6312684" itemprop="comment" itemscope="" itemtype="https://schema.org/Comment"><div class="avatarContainer" data-tooltip-hash="3df3b0b16925b7b26fee8ef374f229ee" data-user-id="6312684" itemprop="author" itemscope="" itemtype="https://schema.org/Person"><div class="avatarImage" data-src="https://avatars.mnstatic.com/noavt_4_80x80.png" title="gabrielsanchezserrano"></div>
# <div class="username userTooltipLauncher" itemprop="name">
#  Gabriel Sanchez Serrano
#  </div></div><div class="textContainer" itemprop="text">
# <h3 class="title" data-translate-content-title="off">Tour gastronómico</h3>
# <div class="content" data-translate-content-text="off"><p>Hace unos meses estuve en Málaga, con unos amigos y decidimos realizar un tour por el centro de la ciudad, pero queríamos hacer algo diferente. Por ello, buscamos por internet y encontramos una empresa que nos ofrecía un tour por el centro de la ciudad, pero visitando el mercado central, varias tiendas gourmet y tres muy buenos restaurantes del centro. La guía, Eva, era muy simpática y tuvimos la suerte de hacer un tour para nosotros 3 solos. Lo que más nos gustó del tour, la cata de vinos malagueños y la variedad en los restaurantes, probamos una porra antequerana en un vegetariano, un flamenquín cordobés en un restaurante tradicional y una paella en el patio, que por lo visto gano un premio a la mejor paella del mundo.</p><div class="whiteOverlay"></div><div class="remainingText"></div></div>
# <div class="linkAction" data-translate-content-text="off" onclick="">
#  Leer más
# </div></div>
# <div class="picturesContainer"></div><div class="buttonsContainer">
# <div class="likeButton" data-likes-count="0" data-poi-id="13124" data-user-id="6312684"><div class="text">
#  Like
#  </div><span class="icon_base icon__like"></span></div> </div></article>]
# data_minube.csv generated

# %% [markdown]
# ##3.3. Recuperación y generación de datos correspondientes al origen 3

# %%
source_3="forocoches"
url_source_3 = urls[source_3]
source_name_3=f"data_{source_3}"
soup = fetch_html(url_source_3)
print(url_source_3)
if soup:
    # 2. Extraer y mostrar el título de la página
    title = soup.title.string
    print(f"Título de la página: {title}")

    # 3. Extraer y mostrar todos los enlaces en la página
    content = soup.find_all('table')
    print(content)
    generate_csv(url_source_3,source_name_3)
# Out:
#  Contenido de la página descargado exitosamente.
# 200
# https://forocoches.com/foro/showthread.php?t=9441037
# Título de la página:  Vivir en málaga - Forocoches
# [<table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Hola,<br>
# <br/>
# Me voy a mudar a Málaga por trabajo y quería preguntar en el foro por zonas/barrios que estén bien para alquilar piso.<br/>
# <br/>
# Agradezco también cualquier otro tipo de consejo para disfrutar de la ciudad.<br/>
# <br/>
# ¡Saludos!
#                 </br></td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Otra pole?
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     En ronda, malaga muy bien
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Perita
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     La cruz verde
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     El alquiler, aquí en general, es una puta mierda.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Estas seguro de que quieres venir a Málaga? Entiendo que vas a cobrar unos 2 5k en adelante netos, de lo contrario probablemente acabes palmando pasta.<br/>
# <br/>
# Los locales nos estamos yendo de aquí básicamente
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     ve lo mas cerca del trabajo, porque en cuanto monten la ZBE como vas a mamar trafico de punta a punta de la ciudad
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Para cuando encuentres piso en Málaga ya ni te acordarás de este hilo.<br/>
# <br/>
# Y espera encontrarte auténticos robos por pisos de mierda.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Te dejo algunas zonas, pero es mejor que digas por qué zona vas a currar o si dispones de aparcamiento privado y/o mierda de la ZBE, porque en algunas de las zonas que te digo no hay forma de aparcar<br/>
# Zonas lujo: limonar, parque clavero, paseo reding, malagueta<br/>
# Zonas buenas: olletas, la victoria (no el rincón, el barrio), ciudad jardin zona nueva construcción<br/>
# <br/>
# Zonas medias : ciudad jardin, el palo,<br/>
# <br/>
# . si te da igual desplazarte mirate La Cala del Moral, Rincon de la victoria, Churriana, Alahurin de la torre, los alamos
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Asperones
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     En qué zona vas a currar shur?<br/>
# Bienvenido
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>MikeSHK</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447377809#post447377809" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>Te dejo algunas zonas, pero es mejor que digas por qué zona vas a currar o si dispones de aparcamiento privado y/o mierda de la ZBE, porque en algunas de las zonas que te digo no hay forma de aparcar<br/>
# Zonas lujo: limonar, parque clavero, paseo reding, malagueta<br/>
# Zonas buenas: olletas, la victoria (no el rincón, el barrio), ciudad jardin zona nueva construcción<br/>
# <br/>
# Zonas medias : ciudad jardin, el palo,<br/>
# <br/>
# . si te da igual desplazarte mirate La Cala del Moral, Rincon de la victoria, Churriana, Alahurin de la torre</div>
# </div>
# </div>
# </div>Eres el mensaje más serio. ¿Dónde dejas teatinos, puerto de la torre y otras zonas que considero buenas? Hay mucho en málaga aunque por desgracia todo es caro.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>Foxandxss</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447378063#post447378063" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>Eres el mensaje más serio. ¿Dónde dejas teatinos, puerto de la torre y otras zonas que considero buenas? Hay mucho en málaga aunque por desgracia todo es caro.</div>
# </div>
# </div>
# </div>Si me he dejado esa zona porque he intentado centrarme en las zonas proximas al centro o menos saturadas<br/>
# otras zonas muy buenas pero caras y lejos son como dices Teatinos, Puerto de la Torre, Parque Litoral, Las piramides... , voy a actualizar el mensaje pero seria ideal que dijera en que zona trabaja, porque lo de la ZBE que se aplica el 1/24 va a ser una follada, sobretodo a gente como yo que vive en el centro y tiene un tractor del 99<br/>
# <br/>
# Segun la futura normativa, si vives en el palo y trabajas en el vialia no se podrá ir por la ciudad si tu coche no cumple la normativa<br/>
# <img alt="" border="0" class="imgpost" src="https://static1.diariosur.es/www/multimedia/202302/09/media/cortadas/zbeMalagaLimpio-kF7H-Rz3oW67juNvSryEGVmgr6XI-624x385@Diario%20Sur.jpg"/><br/>
# <a href="https://www.diariosur.es/malaga-capital/malaga-zona-bajas-emisiones-veto-coches-contaminantes-centro-20230209195649-nt.html" rel="nofollow noopener noreferrer" target="_blank">https://www.diariosur.es/malaga-capi...195649-nt.html</a><br/>
# <br/>
# <br/>
# veo indispensable tener ésto en cuenta antes de asentarse a vivir en málaga
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>Solid_Snake_II</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447377902#post447377902" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>En qué zona vas a currar shur?<br/>
# Bienvenido</div>
# </div>
# </div>
# </div>Trabajaré por la zona de la malagueta. He visto que ese barrio está muy bien y estaría cerca del curro, pero claro, también hay que pagarlo...<br/>
# <br/>
# <br/>
# ¡Gracias por las respuestas!
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Busca por la zona oeste, osease La luz, la paz, puerta blanca, el carpena... En ese orden los pisos irán subiendo de precio
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Mírate por pueblos cercanos. Torremolinos, Benalmadena, Fuengirola... Bien comunicados con el centro por el tren de cercanías.<br/>
# <br/>
# Otra opción como te han dicho, Puerto De la Torre, Churriana (aunque Churriana se está poniendo también caro ya)  <br/>
# <br/>
# <br/>
# Rincón de la Victoria tampoco es mala opción. Algo peor comunicado que la zona oeste de Málaga, pero si no te importa coger el coche, tragar tráfico y pagar parking, puede ser buena alternativa.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>MikeSHK</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447377809#post447377809" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>Te dejo algunas zonas, pero es mejor que digas por qué zona vas a currar o si dispones de aparcamiento privado y/o mierda de la ZBE, porque en algunas de las zonas que te digo no hay forma de aparcar<br/>
# Zonas lujo: limonar, parque clavero, paseo reding, malagueta<br/>
# Zonas buenas: olletas, la victoria (no el rincón, el barrio), ciudad jardin zona nueva construcción<br/>
# <br/>
# Zonas medias : ciudad jardin, el palo,<br/>
# <br/>
# . si te da igual desplazarte mirate La Cala del Moral, Rincon de la victoria, Churriana, Alahurin de la torre, los alamos</div>
# </div>
# </div>
# </div>¡Gracias por la respuesta!<br/>
# <br/>
# Respecto a la ZBE, tengo coche con etiqueta C y por lo que he leído no me afectaría directamente, ¿o hay alguna otra implicación?
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Prepara la cartera si quieres vivir en un piso decente.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>gatuso_19</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447378417#post447378417" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>¡Gracias por la respuesta!<br/>
# <br/>
# Respecto a la ZBE, tengo coche con etiqueta C y por lo que he leído no me afectaría directamente, ¿o hay alguna otra implicación?</div>
# </div>
# </div>
# </div>he actualizado mi mensaje, aqui te dejo el articulo del periodico <a href="https://www.diariosur.es/malaga-capital/malaga-zona-bajas-emisiones-veto-coches-contaminantes-centro-20230209195649-nt.html" rel="nofollow noopener noreferrer" target="_blank">https://www.diariosur.es/malaga-capi...195649-nt.html</a> <br/>
# <br/>
# <br/>
# Si vas a trabajar en la malagueta, sin duda, zona Olletas / Barrio de la Victoria, alquileres desde 900€ pero podrás ir andando al trabajo, por lo que vas a ahorrar en combustible/aparcamiento
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     En los asperones shur!
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     cobro 2000€ netos y soy pobre.<br/>
# <br/>
# Prepárate para los alquileres
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Palmilla. Es lo mas barato
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     ¿Dónde está Málaga?
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Un malaguita por aquí para ayudarte.<br/>
# <br/>
# ¿Podrías ampliar información sobre la zona donde vas a trabajar, edad, soltero/casado, etc? Para poderte aconsejar barrios.<br/>
# <br/>
# Málaga te va a encantar.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Ronda, Málaga si duda. Tienes todo a mano y te plantas en un periquete en plena calle larios si vas en helicóptero.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Dep
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Te deseo suerte.<br/>
# <br/>
# Aqui el alquiler esta muy jodido con el sueldo medio. Ya no es para los malagueños.<br/>
# <br/>
# Antes se podia recomendar zonas por precio y tal, ahora es todo caos y precios muy hinchados.
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
# <div class="squote">
# <div class="quote">
# <div style="display: flex; flex-direction: row; align-items: flex-start; margin-bottom: 8px">
# <div style="display: inline-block">Cita de  <b>gatuso_19</b></div>
# <a alt="Ver Mensaje" href="showthread.php?p=447378251#post447378251" rel="nofollow">
# <span alt="Ver Mensaje" style="background-image: var(--go-to-post); background-repeat: no-repeat; width: 24px; height: 24px; margin-left: 10px; display: flex; background-size: 100%"></span>
# </a>
# </div>
# <div style="word-wrap:break-word; word-break:break-word; font-size: 0.875rem; max-height: 410px; overflow-y: auto">
# <div>Trabajaré por la zona de la malagueta. He visto que ese barrio está muy bien y estaría cerca del curro, pero claro, también hay que pagarlo...<br/>
# <br/>
# <br/>
# ¡Gracias por las respuestas!</div>
# </div>
# </div>
# </div><br/>
# <br/>
# Si, es una zona cara, pero dependiendo de tu presupuesto puedes encontrar algo por la zona este. A ver si tienes suerte!
#                 </td>
# </tr>
# </table>, <table style="width: 100%">
# <tr style="width: 100%">
# <td style="font-size: 1rem; width: 100%">
#
#                     Lo mejor , palma palmilla, asperones, portada alta . Ademas la vivienda y alquiler esta mas baratito por esta zona shur
#                 </td>
# </tr>
# </table>, <table border="0" cellpadding="4" cellspacing="1">
# <tr>
# <td class="thead">Herramientas<a name="goto_threadtools"></a></td>
# </tr>
# <tr>
# <td class="vbmenu_option"><img alt="Mostrar Versión Imprimible" class="inlineimg" src="images/buttons/printer.gif"/> <a accesskey="3" href="printthread.php?t=9441037" rel="nofollow">Mostrar Versión Imprimible</a></td>
# </tr>
# </table>]
# data_forocoches.csv generated

# %%
#4. Descarga de los ficheros csv (posteriormente serán subidos a un repositorio github del cual serán leídos y procesados)

# %%
for file in urls.keys():
  file_name=f"data_{file}"
  files.download(f"{file_name}.csv")
